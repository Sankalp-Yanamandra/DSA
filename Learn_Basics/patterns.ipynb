# %% [markdown]
# <!--
# 1.
#      ***
#      ***
#      ***
#      n rows, n cols each n stars-->

# %%
n = int(input('n = '))

for row in range(n):
    for col in range(n):
        print('*',end="")
    print()# new line for new row

print()

# mtd 2 : pythonic
for row in range(n):
    print('*'*n)
# Out:
# ***
# ***
# ***
#
# ***
# ***
# ***

# %% [markdown]
# # 2.
# ###
# 1
# 12
# 123
# 1234
# ###

# %%
n = int(input('n = '))

print(n)
print('-----')


for row in range(1,n+1):
    for col in range(1,row+1):
        print(col,end="")
    print()# new row : on new line
# Out:
# 4
# -----
# 1
# 12
# 123
# 1234

# %% [markdown]
# ##
# 3.
#
# 1234
# 123
# 12
# 1
# ##

# %%
n = int(input('n = '))
print(n)
print('---')

for row in range(1,n+1):
    limit = (n - row) + 1
    for col in range(1, limit + 1):
        print(col, end="")
    print() # new row on new line
# Out:
# 4
# ---
# 1234
# 123
# 12
# 1

# %% [markdown]
# ##
# 4.
#    *
#   ***
#  *****
# *******
# ##

# %%
n = int(input('n = '))
print(n)
print('----')

for row in range(1,n+1):
    # spaces 1st
    limit = (n - row) + 1
    for space in range(1,limit+1):
        print(' ', end="")


    # # stars 2nd in same line
    # star_count = (2*row) - 1
    # for star in range(star_count):
    #     print('*', end="")

    #print() # new row on new line
    
    # mtd 2 : pythonic ways for stars
    # # stars 2nd in same line
    star_count = (2*row) - 1
    print('*'* star_count)
# Out:
# 3
# ----
#    *
#   ***
#  *****
